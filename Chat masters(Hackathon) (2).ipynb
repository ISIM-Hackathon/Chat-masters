# %%
import nltk
import random
from nltk.chat.util import Chat, reflections

# Define pairs of patterns and responses
pairs = [
    [
        r"hi|hello|hey",
        ["Hello!", "Hey there!", "Hi! How can I help you today?"]
    ],
    [
        r"how are you ?",
        ["I'm doing well, thank you!", "I'm fine, thanks for asking."]
    ],
    [
        r"what is your name ?",
        ["You can call me ChatBot.", "I'm just a chatbot.", "I go by ChatBot."]
    ],
    [
        r"quit|bye|see you",
        ["Goodbye!", "Bye! Have a great day.", "See you later!"]
    ],
    [
        r"your name ?",
        ["My name is ChatBot. What can I assist you with?",]
    ],
    [
        r"PCOD|Polycystic Ovary Syndrome|What is PCOD",
        ["PCOD, or Polycystic Ovarian Disease, is a common hormonal disorder that affects the ovaries. It is characterized by the presence of small cysts on the ovaries and hormonal imbalances.",]
    ],
    [
        r"How common is PCOD?",
        ["PCOD affects about 1 in 10 women of childbearing age."]
    ],
    [
        r"What are the main symptoms of PCOD?",
        ["Irregular periods, excess hair growth, acne, and weight gain are common symptoms of PCOD."]
    ],
    [
        r"Can PCOD cause infertility?",
        ["Yes, PCOD can disrupt ovulation and make it difficult for women to conceive."]
    ],
    [
        r"Is there a cure for PCOD?|cure",
        ["PCOD cannot be cured, but its symptoms can be managed effectively with lifestyle changes and medication."]
    ],
    [
        r"Does PCOD increase the risk of diabetes?",
        ["Yes, women with PCOD are at higher risk of developing type 2 diabetes due to insulin resistance."]
    ],
    [
        r"Can PCOD be diagnosed through blood tests?",
        ["Blood tests can help diagnose PCOD by measuring hormone levels such as testosterone and insulin."]
    ],
    [
        r"How is PCOD treated?",
        ["Treatment for PCOD often involves lifestyle changes such as diet and exercise, along with medication to regulate hormones."]
    ],
    [
        r"Can PCOD lead to complications during pregnancy?",
        ["PCOD increases the risk of complications during pregnancy, including gestational diabetes and preterm birth."]
    ],
    [
        r"What is the link between PCOD and weight gain?",
        ["PCOD can cause weight gain due to insulin resistance and hormonal imbalances."]
    ],
    [
        r"Can PCOD be managed without medication?",
        ["Yes, lifestyle changes such as a healthy diet and regular exercise can help manage PCOD symptoms."]
    ],
    [
        r"Can PCOD affect mental health?",
        ["Yes, PCOD can contribute to anxiety, depression, and body image issues."]
    ],
    [
        r"Are there specific diets recommended for PCOD?",
        ["A balanced diet rich in fruits, vegetables, and whole grains can help manage PCOD symptoms."]
    ],
    [
        r"Can PCOD cause excessive hair growth?",
        ["Yes, PCOD can lead to hirsutism, causing excess hair growth on the face, chest, and back."]
    ],
    [
        r"Can PCOD cause acne?",
        ["Yes, hormonal imbalances associated with PCOD can lead to acne breakouts."]
    ],
    [
        r"Can PCOD cause mood swings?",
        ["Yes, fluctuations in hormone levels can contribute to mood swings in women with PCOD."]
    ],
    [
        r"Can PCOD affect libido?",
        ["Yes, PCOD can lower libido due to hormonal imbalances and other related factors."]
    ],
    [
        r"Can PCOD affect thyroid function?",
        ["Yes, PCOD is often associated with thyroid disorders, such as hypothyroidism."]
    ],
    [
        r"Can PCOD cause sleep disturbances?",
        ["Yes, hormonal imbalances in PCOD can disrupt sleep patterns."]
    ],
    [
        r"Can PCOD increase the risk of heart disease?",
        ["Yes, women with PCOD have a higher risk of developing heart disease due to insulin resistance and other factors."]
    ],
    [
        r"Is PCOD hereditary?",
        ["Yes, PCOD can run in families, suggesting a genetic component."]
    ],
    [
        r"Can PCOD affect bone health?",
        ["Yes, women with PCOD may have lower bone density due to hormonal imbalances."]
    ],
    [
        r"Can PCOD affect fertility in men?",
        ["PCOD is a condition that primarily affects women and does not directly impact male fertility."]
    ],
    [
        r"Can PCOD cause hair loss?",
        ["Yes, PCOD can lead to hair thinning and hair loss in some cases."]
    ],
    [
        r"Can PCOD cause high blood pressure?",
        ["Yes, women with PCOD may be at increased risk of developing high blood pressure."]
    ],
    [
        r"Can PCOD cause miscarriage?",
        ["PCOD can increase the risk of miscarriage due to hormonal imbalances and other related factors."]
    ],
    [
        r"Can PCOD cause irregular bowel movements?",
        ["Yes, PCOD can affect bowel movements in some individuals."]
    ],
    [
        r"Can PCOD cause vision problems?",
        ["PCOD itself does not directly cause vision problems, but certain complications associated with the condition may affect eye health."]
    ],
    [
        r"Can PCOD cause excessive sweating?",
        ["Yes, hormonal imbalances in PCOD can lead to excessive sweating, particularly during periods of hormonal fluctuation."]
    ],
    [
        r"Can PCOD cause migraines?",
        ["Yes, women with PCOD may be at increased risk of experiencing migraines due to hormonal imbalances."]
    ],
    [
        r"Can PCOD cause joint pain?",
        ["Yes, PCOD can contribute to joint pain and stiffness in some individuals."]
    ],
    [
        r"Can PCOD cause digestive issues?",
        ["Yes, hormonal imbalances in PCOD can affect digestion and lead to symptoms such as bloating and abdominal discomfort."]
    ],
    [
        r"Can PCOD cause gallbladder problems?",
        ["Yes, women with PCOD may be at increased risk of developing gallstones and other gallbladder issues."]
    ],
    [
        r"Can PCOD cause breast tenderness?",
        ["Yes, hormonal fluctuations associated with PCOD can cause breast tenderness and swelling."]
    ],
    [
        r"Can PCOD cause kidney problems?",
        ["PCOD itself does not directly cause kidney problems, but certain complications associated with the condition may affect kidney function."]
    ],
    [
        r"Can PCOD cause urinary tract infections?",
        ["PCOD does not directly cause urinary tract infections, but hormonal imbalances and other related factors may increase the risk."]
    ],
    [
        r"Can PCOD cause infertility in men?",
        ["PCOD is a condition that primarily affects women and does not directly impact male fertility."]
    ],
    [
        r"Can PCOD cause seizures?",
        ["PCOD itself does not directly cause seizures, but certain complications associated with the condition may increase the risk in some individuals."]
    ],
    [
        r"Can PCOD cause breast cancer?",
        ["PCOD itself does not directly cause breast cancer, but hormonal imbalances associated with the condition may affect breast health."]
    ],
    [
        r"Can PCOD cause liver problems?",
        ["PCOD does not directly cause liver problems, but certain complications associated with the condition may affect liver function."]
    ],
    [
        r"Can PCOD cause blood clots?",
        ["Yes, women with PCOD may be at increased risk of developing blood clots due to hormonal imbalances and other related factors."]
    ],
    [
        r"Can PCOD cause skin discoloration?",
        ["Yes, hormonal imbalances associated with PCOD can lead to skin discoloration in some individuals."]
    ],
    [
        r"Can PCOD cause hair to become thin?",
        ["Yes, PCOD can lead to hair thinning and hair loss in some cases."]
    ],
    [
        r"Can PCOD cause breast lumps?",
        ["PCOD itself does not directly cause breast lumps, but hormonal imbalances associated with the condition may affect breast health."]
    ],
    [
        r"Can PCOD cause hearing loss?",
        ["PCOD does not directly cause hearing loss, but certain complications associated with the condition may affect ear health."]
    ],
    [
        r"Can PCOD cause asthma?",
        ["PCOD itself does not directly cause asthma, but hormonal imbalances associated with the condition may affect respiratory health."]
    ],
    [
        r"Can PCOD cause blood in urine?",
        ["PCOD itself does not directly cause blood in urine, but certain complications associated with the condition may affect kidney function and urinary health."]
    ],
    [
        r"Can PCOD cause ovarian cancer?",
        ["PCOD itself does not directly cause ovarian cancer, but certain factors associated with the condition may increase the risk."]
    ],
    [
        r"Can PCOD cause dizziness?",
        ["PCOD itself does not directly cause dizziness, but hormonal imbalances associated with the condition may affect balance and coordination in some individuals."]
    ],
    [
        r"Can PCOD cause tingling in hands and feet?",
        ["PCOD itself does not directly cause tingling in hands and feet, but certain complications associated with the condition may affect nerve function and circulation."]
    ],
    [
        r"Is there a cure for PCOD?",
        ["PCOD cannot be cured, but its symptoms can be managed effectively with lifestyle changes and medication."]
    ],
    [
        r"Does PCOD increase the risk of diabetes?",
        ["Yes, women with PCOD are at higher risk of developing type 2 diabetes due to insulin resistance."]
    ],
    [
        r"Can PCOD be diagnosed through blood tests?",
        ["Blood tests can help diagnose PCOD by measuring hormone levels such as testosterone and insulin."]
    ],
    [
        r"Can PCOD lead to complications during pregnancy?",
        ["PCOD increases the risk of complications during pregnancy, including gestational diabetes and preterm birth."]
    ],
    [
        r"What is the link between PCOD and weight gain?",
        ["PCOD can cause weight gain due to insulin resistance and hormonal imbalances."]
    ],
    [
        r"Can PCOD be managed without medication?",
        ["Yes, lifestyle changes such as a healthy diet and regular exercise can help manage PCOD symptoms."]
    ],
    [
        r"Can PCOD affect mental health?",
        ["Yes, PCOD can contribute to anxiety, depression, and body image issues."]
    ],
    [
        r"Are there specific diets recommended for PCOD?",
        ["A balanced diet rich in fruits, vegetables, and whole grains can help manage PCOD symptoms."]
    ],
    [
        r"Can PCOD cause excessive hair growth?|hair growth",
        ["Yes, PCOD can lead to hirsutism, causing excess hair growth on the face, chest, and back."]
    ],
    [
        r"Can PCOD affect thyroid function?",
        ["Yes, PCOD is often associated with thyroid disorders, such as hypothyroidism."]
    ],
    [
        r"Can PCOD cause sleep disturbances?",
        ["Yes, hormonal imbalances in PCOD can disrupt sleep patterns."]
    ],
    [
        r"Is PCOD hereditary?",
        ["Yes, PCOD can run in families, suggesting a genetic component."]
    ],
    [
        r"Can PCOD affect bone health?",
        ["Yes, women with PCOD may have lower bone density due to hormonal imbalances."]
    ],
    [
        r"Can PCOD affect fertility in men?",
        ["PCOD is a condition that primarily affects women and does not directly impact male fertility."]
    ],
    [
        r"Can PCOD cause hair loss?",
        ["Yes, PCOD can lead to hair thinning and hair loss in some cases."]
    ],
    [
        r"Can PCOD cause high blood pressure?",
        ["Yes, women with PCOD may be at increased risk of developing high blood pressure."]
    ],
    [
        r"Can PCOD cause miscarriage?",
        ["PCOD can increase the risk of miscarriage due to hormonal imbalances and other related factors."]
    ],
    [
        r"Can PCOD cause irregular bowel movements?",
        ["Yes, PCOD can affect bowel movements in some individuals."]
    ],
    [
        r"Can PCOD cause vision problems?",
        ["PCOD itself does not directly cause vision problems, but certain complications associated with the condition may affect eye health."]
    ],
    [
        r"Can PCOD cause excessive sweating?",
        ["Yes, hormonal imbalances in PCOD can lead to excessive sweating, particularly during periods of hormonal fluctuation."]
    ],
    [
        r"Can PCOD cause migraines?",
        ["Yes, women with PCOD may be at increased risk of experiencing migraines due to hormonal imbalances."]
    ],
    [
        r"(.*)",
        ["I'm sorry, I didn't quite understand that. Can you please rephrase your question?"]
    ],
    
    
]



# Create a chatbot function
def chatbot():
    print("Hi! I'm ChatBot. How can I assist you today?")
    
    # Create a Chat object
    chat = Chat(pairs, reflections)
    
    # Start conversation
    chat.converse()

    # After quitting the chat, ask if the user wants to determine their diet plan based on age
    choice = input("Do you want to determine your diet plan based on age? (y/n): ")
    if choice.lower() == 'y':
        determine_diet_plan()
    elif choice.lower() == 'n':
        print("Thank you! Have a great day!")
    else:
        print("Invalid choice. Please enter 'y' or 'n'.")

# Function to determine diet plan based on age
def determine_diet_plan():
    age = int(input("Enter your current age: "))
    if 13 <= age <= 19:
        print("This is your diet plan for teenagers. Click the link below.")
        print("https://www.lybrate.com/topic/pcod-diet-chart")
    elif 20 <= age <= 44:
        print("This is your diet plan for adults. Click the link below.")
        print("https://ayu.health/blog/7-day-pcod-diet-plan-for-effective-weight-management/")
    elif 45 <= age <= 60:
        print("This is your diet plan for seniors. Click the link below.")
        print("https://www.artfertilityclinics.com/in/en/art-blog/ultimate-guide-pcod-diet-and-exercise")
    else:
        print("Sorry, we don't have a specific diet plan for your age group.")

if __name__ == "__main__":
    # Initialize NLTK
    nltk.download('punkt')
    
    # Start the chatbot
    chatbot()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\AARUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Hi! I'm ChatBot. How can I assist you today?
